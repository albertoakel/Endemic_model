# %% [markdown]
# # Teste Modelo aclopado

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.integrate import odeint
import lmfit
from lmfit.lineshapes import gaussian, lorentzian
import warnings
import modelos_epidemiologicos as model #

# %% [markdown]
# ### leitura dos dados

# %%
df0= pd.read_parquet("/home/akel/PycharmProjects/Endemic_model/brainstorms/caso_full.parquet")
df0['date']=pd.to_datetime(df0['date'],format='%Y-%m-%d')
dfbel= df0[(df0["city"] == "Belém") & (df0['state']=='PA') ]

# %% [markdown]
# ### Visualização previa

# %%
plt.figure(figsize=(12, 6))  # Tamanho do gráfico

plt.bar(dfbel['date'].values,dfbel['new_confirmed'].values)

# Formatação do gráfico
plt.title('Novos Casos Confirmados de COVID-19 ao Longo do Tempo', fontsize=14)
plt.xlabel('Data', fontsize=12)
plt.ylabel('Número de Novos Casos', fontsize=12)
plt.xticks(rotation=45)  # Rotaciona as datas para melhor legibilidade
plt.grid(True, linestyle='--', alpha=0.6)  # Adiciona grid
plt.tight_layout()
plt.ylim([0,1000])
plt.xlim(pd.to_datetime(['2020-04-01', '2020-07-31']))
# Out:
# (18353.0, 18474.0)

# %%
dfbel['new_confirmed'].iloc[0:120]
dfbel['date'].iloc[0:120]
# Out:
# 1668421   2020-03-18
# 1668423   2020-03-19
# 1668425   2020-03-20
# 1668427   2020-03-21
# 1668429   2020-03-22
#              ...
# 1679957   2020-07-11
# 1680103   2020-07-12
# 1680249   2020-07-13
# 1680395   2020-07-14
# 1680541   2020-07-15
# Name: date, Length: 120, dtype: datetime64[ns]

# %%
plt.figure(figsize=(12, 6))  # Tamanho do gráfico

plt.bar(dfbel['date'].iloc[0:120],dfbel['new_confirmed'].iloc[0:120])



# Formatação do gráfico
plt.title('Novos Casos Confirmados de COVID-19 ao Longo do Tempo', fontsize=14)
plt.xlabel('Data', fontsize=12)
plt.ylabel('Número de Novos Casos', fontsize=12)
plt.xticks(rotation=45)  # Rotaciona as datas para melhor legibilidade
plt.grid(True, linestyle='--', alpha=0.6)  # Adiciona grid
plt.tight_layout()
plt.ylim([0,1000])
c=dfbel['new_confirmed'].iloc[0:120]

# %%
def model_sir(t, N, R, beta,gamma):
    y0 = N-15, 15, R
    out = odeint(model.SIR, y0, t, args=(N, beta, gamma))
    S, I, R = out.T
    return I
    
mod = lmfit.Model(model_sir)


mod.set_param_hint("N", value=100, vary=True) #
mod.set_param_hint("R", value=1, vary=True) #
mod.set_param_hint("beta", value=1, vary=True) #
mod.set_param_hint("gamma", value=1, vary=True) #


#estimador de paramentros
params = mod.make_params()

#parametros do modelo
t=np.linspace(0,119,120)
out = mod.fit(c, params, method="leastsq", t=t)  
N1=out.values['N']
R1=out.values['R']
beta1=out.values['beta']
gamma1=out.values['gamma']


plt.plot(t,model_sir(t, N1, R1, beta1,gamma1),'--')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 21
#      19 #parametros do modelo
#      20 t=np.linspace(0,119,120)
# ---> 21 out = mod.fit(c, params, method="leastsq", t=t)  # fittin
#      22 N1=out.values['N']
#      23 R1=out.values['R']
#
# File ~/anaconda3/envs/data_science/lib/python3.9/site-packages/lmfit/model.py:873, in Model.fit(self, data, params, weights, method, iter_cb, scale_covar, verbose, fit_kws, nan_policy, **kwargs)
#     868     fit_kws = {}
#     870 output = ModelResult(self, params, method=method, iter_cb=iter_cb,
#     871                      scale_covar=scale_covar, fcn_kws=kwargs,
#     872                      nan_policy=self.nan_policy, **fit_kws)
# --> 873 output.fit(data=data, weights=weights)
#     874 output.components = self.components
#     875 return output
#
# File ~/anaconda3/envs/data_science/lib/python3.9/site-packages/lmfit/model.py:1217, in ModelResult.fit(self, data, params, weights, method, nan_policy, **kwargs)
#    1215 self.userkws.update(kwargs)
#    1216 self.init_fit = self.model.eval(params=self.params, **self.userkws)
# -> 1217 _ret = self.minimize(method=self.method)
#    1219 for attr in dir(_ret):
#    1220     if not attr.startswith('_'):
#
# File ~/anaconda3/envs/data_science/lib/python3.9/site-packages/lmfit/minimizer.py:1638, in Minimizer.minimize(self, method, params, **kws)
#    1635         if (key.lower().startswith(user_method) or
#    1636                 val.lower().startswith(user_method)):
#    1637             kwargs['method'] = val
# -> 1638 return function(**kwargs)
#
# File ~/anaconda3/envs/data_science/lib/python3.9/site-packages/lmfit/minimizer.py:1290, in Minimizer.leastsq(self, params, **kws)
#    1287 orig_warn_settings = np.geterr()
#    1288 np.seterr(all='ignore')
# -> 1290 lsout = scipy_leastsq(self.__residual, variables, **lskws)
#    1291 _best, _cov, infodict, errmsg, ier = lsout
#    1292 result.aborted = self._abort
#
# File ~/anaconda3/envs/data_science/lib/python3.9/site-packages/scipy/optimize/_minpack_py.py:420, in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     418 if not isinstance(args, tuple):
#     419     args = (args,)
# --> 420 shape, dtype = _check_func('leastsq', 'func', func, x0, args, n)
#     421 m = shape[0]
#     423 if n > m:
#
# File ~/anaconda3/envs/data_science/lib/python3.9/site-packages/scipy/optimize/_minpack_py.py:29, in _check_func(checker, argname, thefunc, x0, args, numinputs, output_shape)
#      27 def _check_func(checker, argname, thefunc, x0, args, numinputs,
#      28                 output_shape=None):
# ---> 29     res = atleast_1d(thefunc(*((x0[:numinputs],) + args)))
#      30     if (output_shape is not None) and (shape(res) != output_shape):
#      31         if (output_shape[0] != 1):
#
# File ~/anaconda3/envs/data_science/lib/python3.9/site-packages/lmfit/minimizer.py:481, in Minimizer.__residual(self, fvars, apply_bounds_transformation)
#     477 params.update_constraints()
#     479 self.result.nfev += 1
# --> 481 out = self.userfcn(params, *self.userargs, **self.userkws)
#     483 if callable(self.iter_cb):
#     484     abort = self.iter_cb(params, self.result.nfev, out,
#     485                          *self.userargs, **self.userkws)
#
# File ~/anaconda3/envs/data_science/lib/python3.9/site-packages/lmfit/model.py:626, in Model._residual(self, params, data, weights, **kwargs)
#     606 """Return the residual.
#     607
#     608 Default residual: (data-model)*weights.
#    (...)
#     622
#     623 """
#     624 diff = self.eval(params, **kwargs) - data
# --> 626 if diff.dtype == np.complex:
#     627     # data/model are complex
#     628     diff = diff.ravel().view(np.float)
#     629     if weights is not None:
#
# File ~/anaconda3/envs/data_science/lib/python3.9/site-packages/numpy/__init__.py:324, in __getattr__(attr)
#     319     warnings.warn(
#     320         f"In the future `np.{attr}` will be defined as the "
#     321         "corresponding NumPy scalar.", FutureWarning, stacklevel=2)
#     323 if attr in __former_attrs__:
# --> 324     raise AttributeError(__former_attrs__[attr])
#     326 if attr == 'testing':
#     327     import numpy.testing as testing
#
# AttributeError: module 'numpy' has no attribute 'complex'.
# `np.complex` was a deprecated alias for the builtin `complex`. To avoid this error in existing code, use `complex` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.complex128` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
c=dfbel['new_confirmed'].iloc[0:120]
t=np.linspace(0,119,120)
print(c.size)

# %%
beta1=out.values['beta']

# %%
# Define the SIR model differential equations
def sir_model(y, t, N, beta, gamma):
    S, I, R = y
    dSdt = -beta * S * I / N
    dIdt = beta * S * I / N - gamma * I
    dRdt = gamma * I
    return [dSdt, dIdt, dRdt]

# Wrapper function for lmfit
def model_sir(t, N, beta, gamma, I0):
    # Initial conditions: S0 = N-I0, I0, R0=0
    y0 = [N-I0, I0, 0]
    out = odeint(sir_model, y0, t, args=(N, beta, gamma))
    S, I, R = out.T
    return I

# Create lmfit model
mod = lmfit.Model(model_sir)

# Set parameter hints with realistic bounds
mod.set_param_hint("N", value=1000, min=100, max=1e6)  # Total population
mod.set_param_hint("beta", value=0.2, min=0.001, max=2)  # Infection rate
mod.set_param_hint("gamma", value=0.1, min=0.001, max=1)  # Recovery rate
mod.set_param_hint("I0", value=15, min=1, max=1000)  # Initial infected

# Create parameters
params = mod.make_params()

# Time points (days)
t = np.linspace(0, 119, 120)

# Fit the model to your data (replace 'c' with your actual case data)
result = mod.fit(c, params, method="leastsq", t=t)

# Print the fit report
print(result.fit_report())

# Plot results
import matplotlib.pyplot as plt
plt.plot(t, c, 'o', label='Data')
plt.plot(t, result.best_fit, '-', label='Fit')
plt.xlabel('Days')
plt.ylabel('Infected')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 33
#      30 t = np.linspace(0, 119, 120)
#      32 # Fit the model to your data (replace 'c' with your actual case data)
# ---> 33 result = mod.fit(c, params, method="leastsq", t=t)
#      35 # Print the fit report
#      36 print(result.fit_report())
#
# File ~/anaconda3/envs/data_science/lib/python3.9/site-packages/lmfit/model.py:873, in Model.fit(self, data, params, weights, method, iter_cb, scale_covar, verbose, fit_kws, nan_policy, **kwargs)
#     868     fit_kws = {}
#     870 output = ModelResult(self, params, method=method, iter_cb=iter_cb,
#     871                      scale_covar=scale_covar, fcn_kws=kwargs,
#     872                      nan_policy=self.nan_policy, **fit_kws)
# --> 873 output.fit(data=data, weights=weights)
#     874 output.components = self.components
#     875 return output
#
# File ~/anaconda3/envs/data_science/lib/python3.9/site-packages/lmfit/model.py:1217, in ModelResult.fit(self, data, params, weights, method, nan_policy, **kwargs)
#    1215 self.userkws.update(kwargs)
#    1216 self.init_fit = self.model.eval(params=self.params, **self.userkws)
# -> 1217 _ret = self.minimize(method=self.method)
#    1219 for attr in dir(_ret):
#    1220     if not attr.startswith('_'):
#
# File ~/anaconda3/envs/data_science/lib/python3.9/site-packages/lmfit/minimizer.py:1638, in Minimizer.minimize(self, method, params, **kws)
#    1635         if (key.lower().startswith(user_method) or
#    1636                 val.lower().startswith(user_method)):
#    1637             kwargs['method'] = val
# -> 1638 return function(**kwargs)
#
# File ~/anaconda3/envs/data_science/lib/python3.9/site-packages/lmfit/minimizer.py:1290, in Minimizer.leastsq(self, params, **kws)
#    1287 orig_warn_settings = np.geterr()
#    1288 np.seterr(all='ignore')
# -> 1290 lsout = scipy_leastsq(self.__residual, variables, **lskws)
#    1291 _best, _cov, infodict, errmsg, ier = lsout
#    1292 result.aborted = self._abort
#
# File ~/anaconda3/envs/data_science/lib/python3.9/site-packages/scipy/optimize/_minpack_py.py:420, in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     418 if not isinstance(args, tuple):
#     419     args = (args,)
# --> 420 shape, dtype = _check_func('leastsq', 'func', func, x0, args, n)
#     421 m = shape[0]
#     423 if n > m:
#
# File ~/anaconda3/envs/data_science/lib/python3.9/site-packages/scipy/optimize/_minpack_py.py:29, in _check_func(checker, argname, thefunc, x0, args, numinputs, output_shape)
#      27 def _check_func(checker, argname, thefunc, x0, args, numinputs,
#      28                 output_shape=None):
# ---> 29     res = atleast_1d(thefunc(*((x0[:numinputs],) + args)))
#      30     if (output_shape is not None) and (shape(res) != output_shape):
#      31         if (output_shape[0] != 1):
#
# File ~/anaconda3/envs/data_science/lib/python3.9/site-packages/lmfit/minimizer.py:481, in Minimizer.__residual(self, fvars, apply_bounds_transformation)
#     477 params.update_constraints()
#     479 self.result.nfev += 1
# --> 481 out = self.userfcn(params, *self.userargs, **self.userkws)
#     483 if callable(self.iter_cb):
#     484     abort = self.iter_cb(params, self.result.nfev, out,
#     485                          *self.userargs, **self.userkws)
#
# File ~/anaconda3/envs/data_science/lib/python3.9/site-packages/lmfit/model.py:626, in Model._residual(self, params, data, weights, **kwargs)
#     606 """Return the residual.
#     607
#     608 Default residual: (data-model)*weights.
#    (...)
#     622
#     623 """
#     624 diff = self.eval(params, **kwargs) - data
# --> 626 if diff.dtype == np.complex:
#     627     # data/model are complex
#     628     diff = diff.ravel().view(np.float)
#     629     if weights is not None:
#
# File ~/anaconda3/envs/data_science/lib/python3.9/site-packages/numpy/__init__.py:324, in __getattr__(attr)
#     319     warnings.warn(
#     320         f"In the future `np.{attr}` will be defined as the "
#     321         "corresponding NumPy scalar.", FutureWarning, stacklevel=2)
#     323 if attr in __former_attrs__:
# --> 324     raise AttributeError(__former_attrs__[attr])
#     326 if attr == 'testing':
#     327     import numpy.testing as testing
#
# AttributeError: module 'numpy' has no attribute 'complex'.
# `np.complex` was a deprecated alias for the builtin `complex`. To avoid this error in existing code, use `complex` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.complex128` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
