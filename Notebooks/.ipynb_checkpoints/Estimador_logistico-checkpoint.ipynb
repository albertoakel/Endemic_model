# %% [markdown]
# ## Estimador logistco para parâmentros inciais de SIRC

# %%
import numpy as np
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt

# estimador logistico 1
def initial_guess(C):
    """
    Estima os parâmetros iniciais da curva logística usando 3 pontos dos dados C.

    input:
    C : array-like

    Output:
    [K, r, A] ou None
    """
    C = np.array(C)
    n = len(C)
    if n <= 5:
        return None

    for i in range(n - 5):
        k1 = i
        k3 = n - 1
        k2 = (k1 + k3) // 2
        m = k2 - k1

        if m < 1 or any(np.isnan(C[[k1, k2, k3]])):
            continue

        C1, C2, C3 = C[k1], C[k2], C[k3]

        q = C2**2 - C3 * C1
        if q <= 0:
            continue
        p = C1 * C2 - 2 * C1 * C3 + C2 * C3
        if p <= 0:
            continue

        K = C2 * p / q

        try:
            r = np.log((C3 * (C2 - C1)) / (C1 * (C3 - C2))) / m
        except (ZeroDivisionError, ValueError):
            continue
        if r < 0:
            continue

        try:
            A = ((C3 - C2)*(C2 - C1)/q) * \
                ((C3 * (C2 - C1)) / (C1 * (C3 - C2)))**((k3 - m)/m)
        except (ZeroDivisionError, ValueError):
            continue
        if A <= 0:
            continue

        return [K, r, A]

    return None

# %%
# estimador logistico 2
def logistic(t, K, r, A):
    return K / (1 + A * np.exp(-r * t))

def estimate_with_curve_fit(C):
    t = np.arange(len(C))
    C = np.array(C)
    p0 = [max(C)*2, 0.1, 10]  # Chute inicial: K, r, A
    try:
        popt, _ = curve_fit(logistic, t, C, p0=p0, maxfev=10000)
        return popt  # retorna [K, r, A]
    except RuntimeError:
        return None

# %%
dados = [2, 3, 6, 11, 20, 35, 60, 95, 140, 190, 240, 290]

out = initial_guess(dados)
if out:
    K, r, A = out
    print(f"Estimativa inicial:\n  K = {K:.1f}\n  r = {r:.4f}\n  A = {A:.4f}")
else:
    print("Falha na estimativa inicial.")

# %%
t=np.arange(len(dados))

K, r, A = out
logistic = K / (1 + A * np.exp(-r * t))

# valores iniciais a partir da estimativa logistica
Io = K / (A + 1)    #infectados inicias
N = 2 * K           #populacao
gamma = 2 * r       #taxa de recuperacao
beta = 1.5 * gamma  #taxa de contagio

print('Io=',Io)  
print('N=',N)
print('gamma=',gamma)
print('beta=',beta)

plt.plot(t,dados,'ko')
plt.plot(t,logistic)
# Out:
# Io= 1.114669742047541
# N= 983.2558139534884
# gamma= 1.1727911034914515
# beta= 1.7591866552371773

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# Parâmetros do modelo (exemplo numérico)
N = 1000000      # População total
beta = 0.4         # Taxa de transmissão
gamma = 0.1        # Taxa de recuperação
c0 = 0.01          # Fração inicial de casos (1% da população)

# Equação diferencial para dC/dt
def dCdt(C, t, N, beta, gamma, c0):
    c = C / N  # Fração de casos acumulados
    return N * (1 - c) * (beta * c + gamma * np.log((1 - c) / (1 - c0)))

# Tempo (em dias)
t = np.linspace(0, 180, 180)

# Condição inicial
C0 = c0 * N  # Casos iniciais

# Resolvendo a EDO
sol = odeint(dCdt, C0, t, args=(N, beta, gamma, c0))
C = sol.flatten()

# Calculando outras variáveis
c = C / N  # Fração de casos
s = 1 - c  # Suscetíveis
r = -(gamma/beta) * np.log((1 - c)/(1 - c0))  # Recuperados (da equação integrada)
i = c - r  # Infectados ativos

# Plotando os resultados
plt.figure(figsize=(12, 6))
plt.plot(t, C, 'r-', label='Casos acumulados (C)')
plt.plot(t, i*N, 'b-', label='Infectados ativos (I)')
plt.plot(t, r*N, 'g-', label='Recuperados (R)')
plt.title('Modelo SIR em termos de Casos Acumulados')
plt.xlabel('Dias')
plt.ylabel('Número de pessoas')
plt.legend()
plt.grid(True)
plt.show()

# Mostrando valores no dia 180
print(f"No dia 180:")
print(f"- Casos acumulados: {int(C[-1])} ({c[-1]*100:.1f}% da população)")
print(f"- Infectados ativos: {int(i[-1]*N)}")
print(f"- Recuperados: {int(r[-1]*N)}")
# Out:
# No dia 180:
# - Casos acumulados: 980387 (98.0% da população)
# - Infectados ativos: 0
# - Recuperados: 980387
