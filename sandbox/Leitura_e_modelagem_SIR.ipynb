# %% [markdown]
# # Covid-19
# ## Dados consolidadados

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

# %%
df0= pd.read_parquet("caso_full.parquet")
df0['date']=pd.to_datetime(df0['date'],format='%Y-%m-%d')
dfbel= df0[(df0["city"] == "Belém") & (df0['state']=='PA') ]
# dfbel.dtypes

# %%
print(dfbel.isnull().sum())
c=dfbel['new_confirmed']
t=dfbel['date']
print(type(t),t.iloc[1])
#print(type(c))
# Out:
# city                                             0
# city_ibge_code                                   0
# date                                             0
# epidemiological_week                             0
# estimated_population                             0
# estimated_population_2019                        0
# is_last                                          0
# is_repeated                                      0
# last_available_confirmed                         0
# last_available_confirmed_per_100k_inhabitants    0
# last_available_date                              0
# last_available_death_rate                        0
# last_available_deaths                            0
# order_for_place                                  0
# place_type                                       0
# state                                            0
# new_confirmed                                    0
# new_deaths                                       0
# dtype: int64
# <class 'pandas.core.series.Series'> 2020-03-19 00:00:00

# %%
plt.figure(figsize=(12, 6))  # Tamanho do gráfico

plt.bar(dfbel['date'].values,dfbel['new_confirmed'].values)

# Formatação do gráfico
plt.title('Novos Casos Confirmados de COVID-19 ao Longo do Tempo', fontsize=14)
plt.xlabel('Data', fontsize=12)
plt.ylabel('Número de Novos Casos', fontsize=12)
plt.xticks(rotation=45)  # Rotaciona as datas para melhor legibilidade
plt.grid(True, linestyle='--', alpha=0.6)  # Adiciona grid
plt.tight_layout()
plt.ylim([0,1000])
plt.xlim(pd.to_datetime(['2020-04-01', '2020-07-31']))
# Out:
# (18353.0, 18474.0)
